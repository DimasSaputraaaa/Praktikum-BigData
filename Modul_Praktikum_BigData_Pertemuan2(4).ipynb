# %%
print("Hello Word")
print("environment berjalan dengan baik")
# Out:
# Hello Word
# environment berjalan dengan baik

# %%
# cek versi libary
import sys
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

print("pyton\t :", sys.version.split()[0])
print("pandas\t :", pd.__version__)
print("numpy\t :", np.__version__)
print("matplotlib\t :", matplotlib.__version__)
# Out:
# pyton	 : 3.11.16
# pandas	 : 2.2.3
# numpy	 : 1.26.4
# matplotlib	 : 3.8.4

# %%
#tipe data dasar di python
nama_mahasiswa ="budi"
npm = 210411001
ipk = 3.75
aktif_kuliah = True

print(f"Nama\t : {nama_mahasiswa} ({type(nama_mahasiswa).__name__})")
print(f"npm\t : {npm} ({type(npm).__name__})")
print(f"ipk\t : {ipk} ({type(ipk).__name__})")
print(f"aktif\t : {aktif_kuliah} ({type(aktif_kuliah).__name__})")
# Out:
# Nama	 : budi (str)
# npm	 : 210411001 (int)
# ipk	 : 3.75 (float)
# aktif	 : True (bool)

# %%
daftar_nilai = [85, 90, 78, 92, 88] 
print("daftar nilai\t :", daftar_nilai)
print("rata-rata\t :", sum(daftar_nilai) / len(daftar_nilai))

mahasiswa = {
    "nama": "Dimas",
    "npm": 2505060078,
    "jurusan": "Teknoligi Informasi",
    "semester": 3
}
print("\nData mahasiswa: ")
for key, value in mahasiswa.items():
    print(f" {key}: {value}")
# Out:
# daftar nilai	 : [85, 90, 78, 92, 88]
# rata-rata	 : 86.6
#
# Data mahasiswa:
#  nama: Dimas
#  npm: 2505060078
#  jurusan: Teknoligi Informasi
#  semester: 3

# %%
import pandas as pd

data_penjualan = {
    "kota": ["Magelang", "Yogyakarta", "Semarang", "Solo", "Magelang", "Yogyakarta", "Semarang", "Solo"],
    "Minggu": [1, 1, 1, 1, 2, 2, 2, 2],
    "Produk": ["Kaos", "Kaos", "Kaos", "Kaos", "Kaos", "Kaos", "Kaos", "Kaos"],
    "unit_terjual": [120, 95, 150, 80, 135, 110, 160, 90],
    "harga_satuan": [75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000]
}

df = pd.DataFrame(data_penjualan)

df["total_pendapatan"] = df["unit_terjual"] * df["harga_satuan"]

total_per_kota = df.groupby("kota")["total_pendapatan"].sum().sort_values(ascending=False)

print("Total pendapatan per kota (2 minggu): \n")
print(total_per_kota)
# Out:
# Total pendapatan per kota (2 minggu):
#
# kota
# Semarang      23250000
# Magelang      19125000
# Yogyakarta    15375000
# Solo          12750000
# Name: total_pendapatan, dtype: int64

# %%
import pandas as pd

data = {
    'nama': ['Dimas', 'Marsha', 'Delyn', 'Oline', 'Trisha'],
    'uts': [80, 75, 90, 85, 70],
    'uas': [85, 80, 95, 90, 75]
}

df_nilai = pd.DataFrame(data)

df_nilai['nilai_akhir'] = (df_nilai['uts'] * 0.4) + (df_nilai['uas'] * 0.6)

print("Data Nilai Mahasiswa:\n")
print(df_nilai)

hasil = df_nilai[df_nilai['nilai_akhir'] > 80]

print("\nMahasiswa dengan Nilai Akhir di Atas 80:\n")
print(hasil)
# Out:
# Data Nilai Mahasiswa:
#
#      nama  uts  uas  nilai_akhir
# 0   Dimas   80   85         83.0
# 1  Marsha   75   80         78.0
# 2   Delyn   90   95         93.0
# 3   Oline   85   90         88.0
# 4  Trisha   70   75         73.0
#
# Mahasiswa dengan Nilai Akhir di Atas 80:
#
#     nama  uts  uas  nilai_akhir
# 0  Dimas   80   85         83.0
# 2  Delyn   90   95         93.0
# 3  Oline   85   90         88.0
